# %%
#loading the required libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
fifa=pd.read_csv(r"C:\Users\COMP1\Desktop\Software\Projects\players_20.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
#To Know the Size of Data
fifa.shape
# Out:
# (18278, 104)

# %%
#nationality
fifa['nationality'].value_counts().keys()[0:5]
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object', name='nationality')

# %%
#wage_eur
player_salary=fifa[['short_name','wage_eur']]
player_salary.head(10)
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000
# 5       K. De Bruyne    370000
# 6      M. ter Stegen    250000
# 7        V. van Dijk    200000
# 8          L. Modrić    340000
# 9           M. Salah    240000

# %%
#Germany
fifa['nationality']=='Germany'
Germany_players=fifa[fifa['nationality']=='Germany']
Germany_players.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
#Argentina
fifa['nationality']=='Argentina'
Argentina_players=fifa[fifa['nationality']=='Argentina']
Argentina_players.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 0       158023  https://sofifa.com/player/158023/lionel-messi/...
# 17      153079  https://sofifa.com/player/153079/sergio-aguero...
# 23      211110  https://sofifa.com/player/211110/paulo-dybala/...
# 66      183898  https://sofifa.com/player/183898/angel-di-mari...
# 93      201399  https://sofifa.com/player/201399/mauro-icardi/...
# 97      143076  https://sofifa.com/player/143076/alejandro-gom...
# 98      167664  https://sofifa.com/player/167664/gonzalo-higua...
# 159     226226  https://sofifa.com/player/226226/giovani-lo-ce...
# 210     170481  https://sofifa.com/player/170481/ezequiel-gara...
# 213     178562  https://sofifa.com/player/178562/ever-banega/2...
#
#       short_name                          long_name  age         dob  \
# 0       L. Messi     Lionel Andrés Messi Cuccittini   32  1987-06-24
# 17     S. Agüero  Sergio Leonel Agüero del Castillo   31  1988-06-02
# ...

# %%
Argentina_players.sort_values(by=['height_cm'],ascending=True).head()
# Out:
#        sofifa_id                                         player_url  \
# 4829      237994  https://sofifa.com/player/237994/nahuel-barrio...
# 1496      183895  https://sofifa.com/player/183895/maxi-moralez/...
# 15878     241046  https://sofifa.com/player/241046/jonas-romero/...
# 4552      190629  https://sofifa.com/player/190629/daniel-villal...
# 3159      199940  https://sofifa.com/player/199940/juan-ezequiel...
#
#         short_name                        long_name  age         dob  \
# 4829    N. Barrios          Cristian Nahuel Barrios   21  1998-05-07
# 1496    M. Moralez        Maximiliano Nicol Moralez   32  1987-02-27
# 15878    J. Romero                     Jonás Romero   18  2000-08-21
# 4552   D. Villalva  Daniel Alberto Villalba Barrios   26  1992-07-06
# 3159     J. Cuevas             Juan Ezequiel Cuevas   31  1988-06-04
#
#        height_cm  weight_kg nationality                         club  ...  \
# ...

# %%
Argentina_players.sort_values(by=['wage_eur'],ascending=True).head()
# Out:
#        sofifa_id                                         player_url  \
# 17922     246841  https://sofifa.com/player/246841/nicolas-foras...
# 14748     246237  https://sofifa.com/player/246237/ezequiel-bull...
# 14753     247774  https://sofifa.com/player/247774/rodrigo-gonza...
# 14766     232549  https://sofifa.com/player/232549/marcos-peano/...
# 12096     232067  https://sofifa.com/player/232067/neri-bandiera...
#
#           short_name              long_name  age         dob  height_cm  \
# 17922  N. Forastiero     Nicolás Forastiero   20  1998-07-16        182
# 14748    E. Bullaude      Ezequiel Bullaude   18  2000-10-26        184
# 14753    R. González       Rodrigo González   19  2000-04-14        170
# 14766       M. Peano    Marcos Hernán Peano   20  1998-10-15        185
# 12096    N. Bandiera  Neri Ricardo Bandiera   29  1989-07-03        172
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
#Plotting Graph According to the Salary

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary["short_name"])[0:5],list(player_salary["wage_eur"])[0:5],color="r")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="g")
plt.show()

# %%
#shooting

# %%
player_shooting=fifa[["short_name","shooting"]]

# %%
player_shooting.sort_values(by=["shooting"],ascending=True).head()
# Out:
#           short_name  shooting
# 4330   F. Ceccherini      15.0
# 11455  A. Camigliano      16.0
# 16661     L. Polvani      16.0
# 12793     N. Canavan      16.0
# 3695      D. Maietta      16.0

# %%
#defending

# %%
player_defending=fifa[['short_name','defending','nationality']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality
# 16  G. Chiellini       90.0        Italy
# 7    V. van Dijk       90.0  Netherlands
# 11  K. Koulibaly       89.0      Senegal
# 35      D. Godín       89.0      Uruguay
# 49    M. Hummels       89.0      Germany
